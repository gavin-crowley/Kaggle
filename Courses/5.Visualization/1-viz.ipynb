# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
melb = pd.read_csv('../../../Datasets/kaggle/melb_data.csv',index_col="Date", parse_dates=True)

# %%
melb.head()
# Out:
#                  Suburb         Address  Rooms Type    Price Method  \
# Date
# 2017-07-29     Mulgrave     35 Bevis St      3    h  9000000     PI
# 2017-05-13   Canterbury  49 Mangarra Rd      5    h  8000000     VB
# 2017-06-17     Hawthorn    49 Lisson Gr      4    h  7650000      S
# 2016-08-13          Kew     15 Barry St      6    h  6500000      S
# 2017-09-09  Middle Park     136 Page St      5    h  6400000      S
#
#                  SellerG  Distance  Postcode  Bedroom2  Bathroom  Car  \
# Date
# 2017-07-29          Hall      18.8      3170         3         1  1.0
# 2017-05-13     Sotheby's       9.0      3126         5         5  4.0
# 2017-06-17  Abercromby's       5.3      3122         4         2  4.0
# 2016-08-13        Jellis       5.6      3101         6         6  3.0
# 2017-09-09      Marshall       3.0      3206         5         2  1.0
#
#             Landsize  BuildingArea  YearBuilt CouncilArea  Lattitude  \
# Date
# 2017-07-29       744         117.0     1960.0      Monash  -37.93168
# 2017-05-13      2079         464.3     1880.0  Boroondara  -37.81790
# 2017-06-17      1690         284.0     1863.0  Boroondara  -37.82652
# 2016-08-13      1334         365.0     1890.0  Boroondara  -37.80290
# 2017-09-09       553         308.0     1920.0         NaN  -37.84908
#
#             Longtitude                  Regionname  Propertycount
# Date
# 2017-07-29   145.16126  South-Eastern Metropolitan           7113
# 2017-05-13   145.06940       Southern Metropolitan           3265
# 2017-06-17   145.03052       Southern Metropolitan          11308
# 2016-08-13   145.02670       Southern Metropolitan          10331
# 2017-09-09   144.95753       Southern Metropolitan           2019

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=melb)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# comment
