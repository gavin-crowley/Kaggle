# %%
import pandas as pd
melb = pd.read_csv('../../../Datasets/kaggle/melb_data.csv')

# %%
melb.rename(columns={'Price':'SalePrice'})
# Out:
#             Suburb           Address  Rooms Type  SalePrice Method  \
# 0         Mulgrave       35 Bevis St      3    h    9000000     PI
# 1       Canterbury    49 Mangarra Rd      5    h    8000000     VB
# 2         Hawthorn      49 Lisson Gr      4    h    7650000      S
# 3              Kew       15 Barry St      6    h    6500000      S
# 4      Middle Park       136 Page St      5    h    6400000      S
# ...            ...               ...    ...  ...        ...    ...
# 13575     Hawthorn     17/17 Park St      1    u     160000     VB
# 13576       Coburg   171 Moreland Rd      4    h     145000     PI
# 13577       Albion     8/6 Ridley St      1    u     145000     PI
# 13578    Caulfield        30 Pyne St      4    h     131000     PI
# 13579    Footscray  202/51 Gordon St      1    u      85000     PI
#
#             SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0              Hall  29/07/2017      18.8      3170  ...         1  1.0
# ...

# %%
melb.rename(index={0: 'first', 1: 'second'})
# Out:
#              Suburb           Address  Rooms Type    Price Method  \
# first      Mulgrave       35 Bevis St      3    h  9000000     PI
# second   Canterbury    49 Mangarra Rd      5    h  8000000     VB
# 2          Hawthorn      49 Lisson Gr      4    h  7650000      S
# 3               Kew       15 Barry St      6    h  6500000      S
# 4       Middle Park       136 Page St      5    h  6400000      S
# ...             ...               ...    ...  ...      ...    ...
# 13575      Hawthorn     17/17 Park St      1    u   160000     VB
# 13576        Coburg   171 Moreland Rd      4    h   145000     PI
# 13577        Albion     8/6 Ridley St      1    u   145000     PI
# 13578     Caulfield        30 Pyne St      4    h   131000     PI
# 13579     Footscray  202/51 Gordon St      1    u    85000     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# first           Hall  29/07/2017      18.8      3170  ...         1  1.0
# ...

# %%
melb.rename_axis('Houses', axis='rows').rename_axis('Features', axis='columns')
# Out:
# Features       Suburb           Address  Rooms Type    Price Method  \
# Houses
# 0            Mulgrave       35 Bevis St      3    h  9000000     PI
# 1          Canterbury    49 Mangarra Rd      5    h  8000000     VB
# 2            Hawthorn      49 Lisson Gr      4    h  7650000      S
# 3                 Kew       15 Barry St      6    h  6500000      S
# 4         Middle Park       136 Page St      5    h  6400000      S
# ...               ...               ...    ...  ...      ...    ...
# 13575        Hawthorn     17/17 Park St      1    u   160000     VB
# 13576          Coburg   171 Moreland Rd      4    h   145000     PI
# 13577          Albion     8/6 Ridley St      1    u   145000     PI
# 13578       Caulfield        30 Pyne St      4    h   131000     PI
# 13579       Footscray  202/51 Gordon St      1    u    85000     PI
#
# Features       SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# Houses                                                  ...
# ...

# %%
#--------------
#Combining
# combine datasets
pd.concat([canadian_youtube, british_youtube])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-02b240c03c32> in <module>
#       2 #Combining
#       3 # combine datasets
# ----> 4 pd.concat([canadian_youtube, british_youtube])
#
# NameError: name 'canadian_youtube' is not defined

# %%
#join() lets you combine different DataFrame objects which have an index in common
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
