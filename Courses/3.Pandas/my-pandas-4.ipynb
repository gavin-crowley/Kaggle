# %%
#---------------------
#Groupwise analysis

# %%
import pandas as pd
melb = pd.read_csv('../../../Datasets/kaggle/melb_data.csv')
melb.head()
# Out:
#         Suburb         Address  Rooms Type    Price Method       SellerG  \
# 0     Mulgrave     35 Bevis St      3    h  9000000     PI          Hall
# 1   Canterbury  49 Mangarra Rd      5    h  8000000     VB     Sotheby's
# 2     Hawthorn    49 Lisson Gr      4    h  7650000      S  Abercromby's
# 3          Kew     15 Barry St      6    h  6500000      S        Jellis
# 4  Middle Park     136 Page St      5    h  6400000      S      Marshall
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  29/07/2017      18.8      3170  ...         1  1.0       744         117.0
# 1  13/05/2017       9.0      3126  ...         5  4.0      2079         464.3
# 2  17/06/2017       5.3      3122  ...         2  4.0      1690         284.0
# 3  13/08/2016       5.6      3101  ...         6  3.0      1334         365.0
# 4  09/09/2017       3.0      3206  ...         2  1.0       553         308.0
#
# ...

# %%
melb.groupby('Postcode').Postcode.count()
#also, melb.groupby('Postcode').size()
# Out:
# Postcode
# 3000    46
# 3002    22
# 3003    31
# 3006    41
# 3008     3
#         ..
# 3809     1
# 3810     3
# 3910     6
# 3976     4
# 3977     8
# Name: Postcode, Length: 198, dtype: int64

# %%
melb.groupby('Price').Price.min()
# Out:
# Price
# 85000        85000
# 131000      131000
# 145000      145000
# 160000      160000
# 170000      170000
#             ...
# 6400000    6400000
# 6500000    6500000
# 7650000    7650000
# 8000000    8000000
# 9000000    9000000
# Name: Price, Length: 2204, dtype: int64

# %%
melb.groupby('Suburb').apply(lambda df: df.Regionname.iloc[0])
# Out:
# Suburb
# Abbotsford      Northern Metropolitan
# Aberfeldie       Western Metropolitan
# Airport West     Western Metropolitan
# Albanvale        Western Metropolitan
# Albert Park     Southern Metropolitan
#                         ...
# Wonga Park           Eastern Victoria
# Wyndham Vale     Western Metropolitan
# Yallambie       Northern Metropolitan
# Yarra Glen          Northern Victoria
# Yarraville       Western Metropolitan
# Length: 314, dtype: object

# %%
melb.groupby(['Suburb', 'Regionname']).apply(lambda df: df.loc[df.Price.idxmin()])
# Out:
#                                           Suburb              Address  Rooms  \
# Suburb       Regionname
# Abbotsford   Northern Metropolitan    Abbotsford   6/241 Nicholson St      1
# Aberfeldie   Western Metropolitan     Aberfeldie   4/37 St Kinnord St      1
# Airport West Western Metropolitan   Airport West      145a Victory Rd      2
# Albanvale    Western Metropolitan      Albanvale     51a President Rd      2
# Albert Park  Southern Metropolitan   Albert Park     13/52 Moubray St      1
# ...                                          ...                  ...    ...
# Wonga Park   Eastern Victoria         Wonga Park     2 Rindlebrook Pl      3
# Wyndham Vale Western Metropolitan   Wyndham Vale       11 Chisholm Pl      3
# Yallambie    Northern Metropolitan     Yallambie     340 Yallambie Rd      3
# Yarra Glen   Northern Victoria        Yarra Glen          15 Yarra St      3
# Yarraville   Western Metropolitan     Yarraville  3/107 Somerville Rd      2
#
# ...

# %%
#agg(), which lets you run a bunch of different functions on your DataFrame simultaneously

# %%
melb.groupby(['Suburb']).Price.agg([len, min, max])
# Out:
#               len     min      max
# Suburb
# Abbotsford     56  300000  1876000
# Aberfeldie     44  280000  3900000
# Airport West   67  440000  1250000
# Albanvale       6  415000   655000
# Albert Park    69  442500  4735000
# ...           ...     ...      ...
# Wonga Park      1  900000   900000
# Wyndham Vale    4  475000   500000
# Yallambie      24  602500  1670000
# Yarra Glen      1  620000   620000
# Yarraville    164  330000  2450000
#
# [314 rows x 3 columns]

# %%
#-----------------
#Multi-indexes

#Multi-indices have several methods for dealing with their tiered structure which are absent for single-level indices. They also require two levels of labels to retrieve a value.
#However, in general the multi-index method you will use most often is the one for converting back to a regular index, the reset_index() method

address_check = melb.groupby(['Suburb', 'Regionname']).Address.agg([len])
address_check
# Out:
#                                     len
# Suburb       Regionname
# Abbotsford   Northern Metropolitan   56
# Aberfeldie   Western Metropolitan    44
# Airport West Western Metropolitan    67
# Albanvale    Western Metropolitan     6
# Albert Park  Southern Metropolitan   69
# ...                                 ...
# Wonga Park   Eastern Victoria         1
# Wyndham Vale Western Metropolitan     4
# Yallambie    Northern Metropolitan   24
# Yarra Glen   Northern Victoria        1
# Yarraville   Western Metropolitan   164
#
# [314 rows x 1 columns]

# %%
mi = address_check.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
address_check.reset_index()
# Out:
#            Suburb             Regionname  len
# 0      Abbotsford  Northern Metropolitan   56
# 1      Aberfeldie   Western Metropolitan   44
# 2    Airport West   Western Metropolitan   67
# 3       Albanvale   Western Metropolitan    6
# 4     Albert Park  Southern Metropolitan   69
# ..            ...                    ...  ...
# 309    Wonga Park       Eastern Victoria    1
# 310  Wyndham Vale   Western Metropolitan    4
# 311     Yallambie  Northern Metropolitan   24
# 312    Yarra Glen      Northern Victoria    1
# 313    Yarraville   Western Metropolitan  164
#
# [314 rows x 3 columns]

# %%
#Sorting

# %%
address_check = address_check.reset_index()
address_check.sort_values(by='len', ascending=True)
# Out:
#      level_0  index          Suburb                  Regionname  len
# 201      201    201        Montrose            Eastern Victoria    1
# 291      291    291          Wallan           Northern Victoria    1
# 149      149    149     Healesville           Northern Victoria    1
# 44        44     44      Brookfield            Western Victoria    1
# 247      247    247       Sandhurst  South-Eastern Metropolitan    1
# ..       ...    ...             ...                         ...  ...
# 46        46     46       Brunswick       Northern Metropolitan  222
# 234      234    234         Preston       Northern Metropolitan  239
# 30        30     30  Bentleigh East       Southern Metropolitan  249
# 237      237    237        Richmond       Northern Metropolitan  260
# 236      236    236       Reservoir       Northern Metropolitan  359
#
# [314 rows x 5 columns]

# %%
address_check.sort_index()
# Out:
#      level_0  index        Suburb             Regionname  len
# 0          0      0    Abbotsford  Northern Metropolitan   56
# 1          1      1    Aberfeldie   Western Metropolitan   44
# 2          2      2  Airport West   Western Metropolitan   67
# 3          3      3     Albanvale   Western Metropolitan    6
# 4          4      4   Albert Park  Southern Metropolitan   69
# ..       ...    ...           ...                    ...  ...
# 309      309    309    Wonga Park       Eastern Victoria    1
# 310      310    310  Wyndham Vale   Western Metropolitan    4
# 311      311    311     Yallambie  Northern Metropolitan   24
# 312      312    312    Yarra Glen      Northern Victoria    1
# 313      313    313    Yarraville   Western Metropolitan  164
#
# [314 rows x 5 columns]

# %%
address_check.sort_values(by=['Suburb', 'len'])
# Out:
#      level_0  index        Suburb             Regionname  len
# 0          0      0    Abbotsford  Northern Metropolitan   56
# 1          1      1    Aberfeldie   Western Metropolitan   44
# 2          2      2  Airport West   Western Metropolitan   67
# 3          3      3     Albanvale   Western Metropolitan    6
# 4          4      4   Albert Park  Southern Metropolitan   69
# ..       ...    ...           ...                    ...  ...
# 309      309    309    Wonga Park       Eastern Victoria    1
# 310      310    310  Wyndham Vale   Western Metropolitan    4
# 311      311    311     Yallambie  Northern Metropolitan   24
# 312      312    312    Yarra Glen      Northern Victoria    1
# 313      313    313    Yarraville   Western Metropolitan  164
#
# [314 rows x 5 columns]

# %%
#--------------------------
#Qs

# %%
suburb_mean = melb.groupby('Suburb')['Price'].mean().sort_index()
suburb_mean
# Out:
# Suburb
# Abbotsford      1.060366e+06
# Aberfeldie      1.277455e+06
# Airport West    7.566567e+05
# Albanvale       5.370833e+05
# Albert Park     1.941355e+06
#                     ...
# Wonga Park      9.000000e+05
# Wyndham Vale    4.832500e+05
# Yallambie       8.396875e+05
# Yarra Glen      6.200000e+05
# Yarraville      9.886155e+05
# Name: Price, Length: 314, dtype: float64

# %%
suburb_counts = melb.groupby(['Suburb', 'Regionname']).size().sort_values(ascending=False)
suburb_counts
# Out:
# Suburb              Regionname
# Reservoir           Northern Metropolitan         359
# Richmond            Northern Metropolitan         260
# Bentleigh East      Southern Metropolitan         249
# Preston             Northern Metropolitan         239
# Brunswick           Northern Metropolitan         222
#                                                  ...
# Attwood             Northern Metropolitan           1
# Beaconsfield Upper  Eastern Victoria                1
# Bacchus Marsh       Western Victoria                1
# Sandhurst           South-Eastern Metropolitan      1
# Officer             Eastern Victoria                1
# Length: 314, dtype: int64
