# %%
#==================================
# Creating, Reading and Writing

# %%
import pandas as pd

# %%
#A DataFrame is a table. It contains an array of individual entries, each of which has a certain value

# %%
#Create a simple Datframe
pd.DataFrame({'Price': [250000], 'Bedrooms': [3]})
# Out:
#     Price  Bedrooms
# 0  250000         3

# %%
pd.DataFrame({'Price': [250000, 120000], 'Bedrooms': [3, 1]})
# Out:
#     Price  Bedrooms
# 0  250000         3
# 1  120000         1

# %%
pd.DataFrame({'Price': [250000, 120000], 'Bedrooms': [3, 1]}, index=['House 1', 'House 2'])
# Out:
#           Price  Bedrooms
# House 1  250000         3
# House 2  120000         1

# %%
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list.
# A Series is, in essence, a single column of a DataFrame
# a Series does not have a column name, it only has one overall name

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([200000, 233000, 250000], index=['2018', '2019', '2020'], name = 'House Prices')
# Out:
# 2018    200000
# 2019    233000
# 2020    250000
# Name: House Prices, dtype: int64

# %%
# It's helpful to think of a DataFrame as actually being just a bunch of Series "glued together".

# %%
melb_data = pd.read_csv('../../../Datasets/kaggle/melb_data.csv')

# %%
melb_data.shape
# Out:
# (13580, 21)

# %%
melb_data.head()
# Out:
#         Suburb         Address  Rooms Type    Price Method       SellerG  \
# 0     Mulgrave     35 Bevis St      3    h  9000000     PI          Hall
# 1   Canterbury  49 Mangarra Rd      5    h  8000000     VB     Sotheby's
# 2     Hawthorn    49 Lisson Gr      4    h  7650000      S  Abercromby's
# 3          Kew     15 Barry St      6    h  6500000      S        Jellis
# 4  Middle Park     136 Page St      5    h  6400000      S      Marshall
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  29/07/2017      18.8      3170  ...         1  1.0       744         117.0
# 1  13/05/2017       9.0      3126  ...         5  4.0      2079         464.3
# 2  17/06/2017       5.3      3122  ...         2  4.0      1690         284.0
# 3  13/08/2016       5.6      3101  ...         6  3.0      1334         365.0
# 4  09/09/2017       3.0      3206  ...         2  1.0       553         308.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude                  Regionname  \
# 0     1960.0       Monash -37.93168   145.16126  South-Eastern Metropolitan
# 1     1880.0   Boroondara -37.81790   145.06940       Southern Metropolitan
# 2     1863.0   Boroondara -37.82652   145.03052       Southern Metropolitan
# 3     1890.0   Boroondara -37.80290   145.02670       Southern Metropolitan
# 4     1920.0          NaN -37.84908   144.95753       Southern Metropolitan
#
#   Propertycount
# 0          7113
# 1          3265
# 2         11308
# 3         10331
# 4          2019
#
# [5 rows x 21 columns]

# %%
house_write_test = pd.DataFrame({'Price': [250000, 120000], 'Bedrooms': [3, 1]}, index=['House 1', 'House 2'])

# %%
house_write_test.to_csv('write_test.csv')

# %%
#================================
#Indexing, Selecting & Assigning

# %%
#Native Python accessor objects provide good ways of indexing data. Pandas carries all of these over

# %%
melb_data.Price
# Out:
# 0        9000000
# 1        8000000
# 2        7650000
# 3        6500000
# 4        6400000
#           ...
# 13575     160000
# 13576     145000
# 13577     145000
# 13578     131000
# 13579      85000
# Name: Price, Length: 13580, dtype: int64

# %%
melb_data['Price']
# Out:
# 0        9000000
# 1        8000000
# 2        7650000
# 3        6500000
# 4        6400000
#           ...
# 13575     160000
# 13576     145000
# 13577     145000
# 13578     131000
# 13579      85000
# Name: Price, Length: 13580, dtype: int64

# %%
melb_data['Price'][0]
# Out:
# 9000000

# %%
#pandas has its own accessor operators, loc and iloc. For more advanced operations, these are the ones you're supposed to be using

# %%
#select first value in Suburb
melb_data.Suburb.iloc[0]
# Out:
# 'Mulgrave'

# %%
#retrieve a row
melb_data.iloc[0]
# Out:
# Suburb                             Mulgrave
# Address                         35 Bevis St
# Rooms                                     3
# Type                                      h
# Price                               9000000
# Method                                   PI
# SellerG                                Hall
# Date                             29/07/2017
# Distance                               18.8
# Postcode                               3170
# Bedroom2                                  3
# Bathroom                                  1
# Car                                     1.0
# Landsize                                744
# BuildingArea                          117.0
# YearBuilt                            1960.0
# CouncilArea                          Monash
# Lattitude                         -37.93168
# Longtitude                        145.16126
# Regionname       South-Eastern Metropolitan
# Propertycount                          7113
# Name: 0, dtype: object

# %%
# Both loc and iloc are row-first, column-second. This is the opposite of what we do in native Python, which is column-first, row-second.

# %%
#retrieve a column
melb_data.iloc[:, 0]
# Out:
# 0           Mulgrave
# 1         Canterbury
# 2           Hawthorn
# 3                Kew
# 4        Middle Park
#             ...
# 13575       Hawthorn
# 13576         Coburg
# 13577         Albion
# 13578      Caulfield
# 13579      Footscray
# Name: Suburb, Length: 13580, dtype: object

# %%
# On its own, the : operator, which also comes from native Python, means "everything"

# %%
melb_data.iloc[:3, 0]
# Out:
# 0      Mulgrave
# 1    Canterbury
# 2      Hawthorn
# Name: Suburb, dtype: object

# %%
melb_data.iloc[1:3, 0]
# Out:
# 1    Canterbury
# 2      Hawthorn
# Name: Suburb, dtype: object

# %%
melb_data.iloc[[0,1,2], 0]
# Out:
# 0      Mulgrave
# 1    Canterbury
# 2      Hawthorn
# Name: Suburb, dtype: object

# %%
melb_data.iloc[-5:]
# Out:
#           Suburb           Address  Rooms Type   Price Method  SellerG  \
# 13575   Hawthorn     17/17 Park St      1    u  160000     VB      HAR
# 13576     Coburg   171 Moreland Rd      4    h  145000     PI   Jellis
# 13577     Albion     8/6 Ridley St      1    u  145000     PI   Biggin
# 13578  Caulfield        30 Pyne St      4    h  131000     PI   Rodney
# 13579  Footscray  202/51 Gordon St      1    u   85000     PI  Burnham
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  08/04/2017       4.6      3122  ...         1  0.0       322
# 13576  04/06/2016       7.8      3058  ...         1  1.0       536
# 13577  28/05/2016      13.9      3020  ...         1  1.0        36
# 13578  25/02/2017       8.9      3162  ...         1  2.0       499
# 13579  03/09/2016       6.4      3011  ...         1  0.0         0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 13575           NaN     2009.0   Boroondara  -37.8198    145.0373
# 13576         164.0     1910.0     Moreland  -37.7555    144.9658
# 13577           NaN        NaN     Brimbank  -37.7833    144.8266
# 13578         155.0     1920.0    Glen Eira  -37.8864    145.0242
# 13579           NaN     2007.0  Maribyrnong  -37.7911    144.8900
#
#                   Regionname Propertycount
# 13575  Southern Metropolitan         11308
# 13576  Northern Metropolitan         11204
# 13577   Western Metropolitan          2185
# 13578  Southern Metropolitan          2379
# 13579   Western Metropolitan          7570
#
# [5 rows x 21 columns]

# %%
# Label-based selection
# The second paradigm for attribute selection is the one followed by the loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters.

# %%
melb_data.loc[0, 'Suburb']
# Out:
# 'Mulgrave'

# %%
# iloc is conceptually simpler than loc because it ignores the dataset's indices. When we use iloc we treat the dataset like a big matrix (a list of lists), one that we have to index into by position. loc, by contrast, uses the information in the indices to do its work. Since your dataset usually has meaningful indices, it's usually easier to do things using loc instead. For example, here's one operation that's much easier using loc:

# %%
pd.DataFrame(melb_data.loc[0:2:, ['Rooms', 'Type', 'Price' ]])
# Out:
#    Rooms  Type    Price
# 0      3  sold  9000000
# 1      5  sold  8000000
# 2      4  sold  7650000

# %%
melb_data.loc[:, ['Rooms', 'Type', 'Price' ]]
# Out:
#        Rooms  Type    Price
# 0          3  sold  9000000
# 1          5  sold  8000000
# 2          4  sold  7650000
# 3          6  sold  6500000
# 4          5  sold  6400000
# ...      ...   ...      ...
# 13575      1  sold   160000
# 13576      4  sold   145000
# 13577      1  sold   145000
# 13578      4  sold   131000
# 13579      1  sold    85000
#
# [13580 rows x 3 columns]

# %%
melb_data.loc[[1,52,2673], ['Rooms', 'Type', 'Price' ]]
# Out:
#       Rooms  Type    Price
# 1         5  sold  8000000
# 52        4  sold  4050000
# 2673      2  sold  1460000

# %%
# cols = ['country', 'province', 'region_1', 'region_2']
# df = pd.DataFrame(reviews.loc[[0,1,10,100],cols])

# %%
# When choosing or transitioning between loc and iloc, there is one "gotcha" worth keeping in mind, which is that the two methods use slightly different indexing schemes.

# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10

# %%
# Manipulating the index

# %%
melb_data.head()
# Out:
#         Suburb         Address  Rooms Type    Price Method       SellerG  \
# 0     Mulgrave     35 Bevis St      3    h  9000000     PI          Hall
# 1   Canterbury  49 Mangarra Rd      5    h  8000000     VB     Sotheby's
# 2     Hawthorn    49 Lisson Gr      4    h  7650000      S  Abercromby's
# 3          Kew     15 Barry St      6    h  6500000      S        Jellis
# 4  Middle Park     136 Page St      5    h  6400000      S      Marshall
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  29/07/2017      18.8      3170  ...         1  1.0       744         117.0
# 1  13/05/2017       9.0      3126  ...         5  4.0      2079         464.3
# 2  17/06/2017       5.3      3122  ...         2  4.0      1690         284.0
# 3  13/08/2016       5.6      3101  ...         6  3.0      1334         365.0
# 4  09/09/2017       3.0      3206  ...         2  1.0       553         308.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude                  Regionname  \
# 0     1960.0       Monash -37.93168   145.16126  South-Eastern Metropolitan
# 1     1880.0   Boroondara -37.81790   145.06940       Southern Metropolitan
# 2     1863.0   Boroondara -37.82652   145.03052       Southern Metropolitan
# 3     1890.0   Boroondara -37.80290   145.02670       Southern Metropolitan
# 4     1920.0          NaN -37.84908   144.95753       Southern Metropolitan
#
#   Propertycount
# 0          7113
# 1          3265
# 2         11308
# 3         10331
# 4          2019
#
# [5 rows x 21 columns]

# %%
# This is useful if you can come up with an index for the dataset which is better than the current one
melb_data.set_index('Index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-94309a0d0023> in <module>
#       1 # This is useful if you can come up with an index for the dataset which is better than the current one
# ----> 2 melb_data.set_index('Index')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['Index'] are in the columns"

# %%
#----------------------
# Conditional selection

# %%
melb_data.Suburb == 'Hawthorn'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 13575     True
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Name: Suburb, Length: 13580, dtype: bool

# %%
melb_data.loc[melb_data.Suburb == 'Hawthorn']
# Out:
#          Suburb               Address  Rooms Type    Price Method  \
# 2      Hawthorn          49 Lisson Gr      4    h  7650000      S
# 10     Hawthorn        17 Fairview St      5    h  5510000      S
# 15     Hawthorn        49 Berkeley St      3    h  5100000      S
# 18     Hawthorn         50 Kinkora Rd      4    h  5050000     VB
# 41     Hawthorn         2 Fordholm Rd      5    h  4250000     PI
# ...         ...                   ...    ...  ...      ...    ...
# 13440  Hawthorn      4/162 Barkers Rd      1    h   300000     VB
# 13456  Hawthorn  11/140 Riversdale Rd      1    u   292000      S
# 13466  Hawthorn  13/506 Glenferrie Rd      1    u   290000      S
# 13504  Hawthorn     12/5 Summerlea Gr      1    u   275000     SP
# 13575  Hawthorn         17/17 Park St      1    u   160000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 2       Abercromby's  17/06/2017       5.3      3122  ...         2  4.0
# 10                RT  03/06/2017       5.3      3122  ...         2  5.0
# 15            Jellis  03/12/2016       4.6      3122  ...         2  3.0
# 18               Kay  19/11/2016       4.6      3122  ...         4  2.0
# 41          Marshall  17/09/2016       4.6      3122  ...         4  3.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 13440            Ray  13/05/2017       4.6      3122  ...         1  1.0
# 13456       Woodards  07/11/2016       4.6      3122  ...         1  0.0
# 13466         Biggin  22/05/2016       4.6      3122  ...         1  1.0
# 13504  hockingstuart  13/05/2017       4.6      3122  ...         1  0.0
# 13575            HAR  08/04/2017       4.6      3122  ...         1  0.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 2          1690         284.0     1863.0   Boroondara -37.82652   145.03052
# 10          820         300.0     1971.0   Boroondara -37.83031   145.02973
# 15         1038           NaN        NaN   Boroondara -37.83320   145.03660
# 18          905         373.0     1913.0   Boroondara -37.81680   145.03210
# 41         1275         435.0     1930.0   Boroondara -37.82910   145.03080
# ...         ...           ...        ...          ...       ...         ...
# 13440         0           NaN        NaN   Boroondara -37.81430   145.03190
# 13456         0          56.0     1966.0   Boroondara -37.82940   145.03820
# 13466      1568           NaN        NaN   Boroondara -37.83080   145.03400
# 13504       479          30.0     1970.0   Boroondara -37.82920   145.03220
# 13575       322           NaN     2009.0   Boroondara -37.81980   145.03730
#
#                   Regionname Propertycount
# 2      Southern Metropolitan         11308
# 10     Southern Metropolitan         11308
# 15     Southern Metropolitan         11308
# 18     Southern Metropolitan         11308
# 41     Southern Metropolitan         11308
# ...                      ...           ...
# 13440  Southern Metropolitan         11308
# 13456  Southern Metropolitan         11308
# 13466  Southern Metropolitan         11308
# 13504  Southern Metropolitan         11308
# 13575  Southern Metropolitan         11308
#
# [191 rows x 21 columns]

# %%
melb_data.loc[(melb_data.Suburb == 'Hawthorn') & (melb_data.Price > 500000)]
# Out:
#          Suburb          Address  Rooms Type    Price Method       SellerG  \
# 2      Hawthorn     49 Lisson Gr      4    h  7650000      S  Abercromby's
# 10     Hawthorn   17 Fairview St      5    h  5510000      S            RT
# 15     Hawthorn   49 Berkeley St      3    h  5100000      S        Jellis
# 18     Hawthorn    50 Kinkora Rd      4    h  5050000     VB           Kay
# 41     Hawthorn    2 Fordholm Rd      5    h  4250000     PI      Marshall
# ...         ...              ...    ...  ...      ...    ...           ...
# 11709  Hawthorn  13/177 Power St      2    u   525000      S        Biggin
# 11717  Hawthorn  14/181 Power St      2    u   525000     PI        Walshe
# 11721  Hawthorn  3/199 Auburn Rd      2    u   525000     SP      Marshall
# 11756  Hawthorn  3/18 Connell St      2    u   520000     PI       CASTRAN
# 11815  Hawthorn   4/178 Power St      2    u   517000      S        Jellis
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 2      17/06/2017       5.3      3122  ...         2  4.0      1690
# 10     03/06/2017       5.3      3122  ...         2  5.0       820
# 15     03/12/2016       4.6      3122  ...         2  3.0      1038
# 18     19/11/2016       4.6      3122  ...         4  2.0       905
# 41     17/09/2016       4.6      3122  ...         4  3.0      1275
# ...           ...       ...       ...  ...       ...  ...       ...
# 11709  07/11/2016       4.6      3122  ...         1  1.0         0
# 11717  17/06/2017       5.3      3122  ...         1  1.0         0
# 11721  27/05/2017       5.3      3122  ...         1  1.0       279
# 11756  13/08/2016       4.6      3122  ...         1  1.0         0
# 11815  14/05/2016       4.6      3122  ...         1  1.0         0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 2             284.0     1863.0   Boroondara -37.82652   145.03052
# 10            300.0     1971.0   Boroondara -37.83031   145.02973
# 15              NaN        NaN   Boroondara -37.83320   145.03660
# 18            373.0     1913.0   Boroondara -37.81680   145.03210
# 41            435.0     1930.0   Boroondara -37.82910   145.03080
# ...             ...        ...          ...       ...         ...
# 11709           NaN        NaN   Boroondara -37.82650   145.02570
# 11717           NaN        NaN   Boroondara -37.82700   145.02563
# 11721           NaN        NaN   Boroondara -37.82676   145.04444
# 11756           NaN        NaN   Boroondara -37.81850   145.02350
# 11815           NaN        NaN   Boroondara -37.82610   145.02540
#
#                   Regionname Propertycount
# 2      Southern Metropolitan         11308
# 10     Southern Metropolitan         11308
# 15     Southern Metropolitan         11308
# 18     Southern Metropolitan         11308
# 41     Southern Metropolitan         11308
# ...                      ...           ...
# 11709  Southern Metropolitan         11308
# 11717  Southern Metropolitan         11308
# 11721  Southern Metropolitan         11308
# 11756  Southern Metropolitan         11308
# 11815  Southern Metropolitan         11308
#
# [143 rows x 21 columns]

# %%
melb_data.loc[(melb_data.Suburb == 'Hawthorn') | (melb_data.Price > 500000)]
# Out:
#             Suburb               Address  Rooms Type    Price Method  \
# 0         Mulgrave           35 Bevis St      3    h  9000000     PI
# 1       Canterbury        49 Mangarra Rd      5    h  8000000     VB
# 2         Hawthorn          49 Lisson Gr      4    h  7650000      S
# 3              Kew           15 Barry St      6    h  6500000      S
# 4      Middle Park           136 Page St      5    h  6400000      S
# ...            ...                   ...    ...  ...      ...    ...
# 13440     Hawthorn      4/162 Barkers Rd      1    h   300000     VB
# 13456     Hawthorn  11/140 Riversdale Rd      1    u   292000      S
# 13466     Hawthorn  13/506 Glenferrie Rd      1    u   290000      S
# 13504     Hawthorn     12/5 Summerlea Gr      1    u   275000     SP
# 13575     Hawthorn         17/17 Park St      1    u   160000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0               Hall  29/07/2017      18.8      3170  ...         1  1.0
# 1          Sotheby's  13/05/2017       9.0      3126  ...         5  4.0
# 2       Abercromby's  17/06/2017       5.3      3122  ...         2  4.0
# 3             Jellis  13/08/2016       5.6      3101  ...         6  3.0
# 4           Marshall  09/09/2017       3.0      3206  ...         2  1.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 13440            Ray  13/05/2017       4.6      3122  ...         1  1.0
# 13456       Woodards  07/11/2016       4.6      3122  ...         1  0.0
# 13466         Biggin  22/05/2016       4.6      3122  ...         1  1.0
# 13504  hockingstuart  13/05/2017       4.6      3122  ...         1  0.0
# 13575            HAR  08/04/2017       4.6      3122  ...         1  0.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0           744         117.0     1960.0       Monash -37.93168   145.16126
# 1          2079         464.3     1880.0   Boroondara -37.81790   145.06940
# 2          1690         284.0     1863.0   Boroondara -37.82652   145.03052
# 3          1334         365.0     1890.0   Boroondara -37.80290   145.02670
# 4           553         308.0     1920.0          NaN -37.84908   144.95753
# ...         ...           ...        ...          ...       ...         ...
# 13440         0           NaN        NaN   Boroondara -37.81430   145.03190
# 13456         0          56.0     1966.0   Boroondara -37.82940   145.03820
# 13466      1568           NaN        NaN   Boroondara -37.83080   145.03400
# 13504       479          30.0     1970.0   Boroondara -37.82920   145.03220
# 13575       322           NaN     2009.0   Boroondara -37.81980   145.03730
#
#                        Regionname Propertycount
# 0      South-Eastern Metropolitan          7113
# 1           Southern Metropolitan          3265
# 2           Southern Metropolitan         11308
# 3           Southern Metropolitan         10331
# 4           Southern Metropolitan          2019
# ...                           ...           ...
# 13440       Southern Metropolitan         11308
# 13456       Southern Metropolitan         11308
# 13466       Southern Metropolitan         11308
# 13504       Southern Metropolitan         11308
# 13575       Southern Metropolitan         11308
#
# [12031 rows x 21 columns]

# %%
#isin is lets you select data whose value "is in" a list of values
melb_data.loc[melb_data.Suburb.isin(['Hawthorn', 'Armadale'])]
# Out:
#          Suburb               Address  Rooms Type    Price Method  \
# 2      Hawthorn          49 Lisson Gr      4    h  7650000      S
# 9      Armadale      367 Dandenong Rd      6    h  5525000      S
# 10     Hawthorn        17 Fairview St      5    h  5510000      S
# 14     Armadale        52 Adelaide St      5    h  5200000     SP
# 15     Hawthorn        49 Berkeley St      3    h  5100000      S
# ...         ...                   ...    ...  ...      ...    ...
# 13456  Hawthorn  11/140 Riversdale Rd      1    u   292000      S
# 13466  Hawthorn  13/506 Glenferrie Rd      1    u   290000      S
# 13485  Armadale   15/405 Dandenong Rd      1    u   280000     PI
# 13504  Hawthorn     12/5 Summerlea Gr      1    u   275000     SP
# 13575  Hawthorn         17/17 Park St      1    u   160000     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 2       Abercromby's  17/06/2017       5.3      3122  ...         2  4.0
# 9           Marshall  17/09/2016       6.3      3143  ...         3  4.0
# 10                RT  03/06/2017       5.3      3122  ...         2  5.0
# 14          Marshall  01/07/2017       6.3      3143  ...         3  3.0
# 15            Jellis  03/12/2016       4.6      3122  ...         2  3.0
# ...              ...         ...       ...       ...  ...       ...  ...
# 13456       Woodards  07/11/2016       4.6      3122  ...         1  0.0
# 13466         Biggin  22/05/2016       4.6      3122  ...         1  1.0
# 13485  hockingstuart  10/09/2016       6.3      3143  ...         1  1.0
# 13504  hockingstuart  13/05/2017       4.6      3122  ...         1  0.0
# 13575            HAR  08/04/2017       4.6      3122  ...         1  0.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 2          1690         284.0     1863.0   Boroondara -37.82652   145.03052
# 9          1491         516.0     1935.0  Stonnington -37.86020   145.01300
# 10          820         300.0     1971.0   Boroondara -37.83031   145.02973
# 14          761           NaN        NaN  Stonnington -37.85311   145.02847
# 15         1038           NaN        NaN   Boroondara -37.83320   145.03660
# ...         ...           ...        ...          ...       ...         ...
# 13456         0          56.0     1966.0   Boroondara -37.82940   145.03820
# 13466      1568           NaN        NaN   Boroondara -37.83080   145.03400
# 13485         0          38.0     1975.0  Stonnington -37.86190   145.01850
# 13504       479          30.0     1970.0   Boroondara -37.82920   145.03220
# 13575       322           NaN     2009.0   Boroondara -37.81980   145.03730
#
#                   Regionname Propertycount
# 2      Southern Metropolitan         11308
# 9      Southern Metropolitan          4836
# 10     Southern Metropolitan         11308
# 14     Southern Metropolitan          4836
# 15     Southern Metropolitan         11308
# ...                      ...           ...
# 13456  Southern Metropolitan         11308
# 13466  Southern Metropolitan         11308
# 13485  Southern Metropolitan          4836
# 13504  Southern Metropolitan         11308
# 13575  Southern Metropolitan         11308
#
# [286 rows x 21 columns]

# %%
# The second is isnull (and its companion notnull). These methods let you highlight values which are (or are not) empty (NaN).
melb_data.loc[melb_data.Car.isnull()]
# Out:
#                 Suburb            Address  Rooms Type    Price Method  \
# 456        Albert Park  123 Richardson St      4    h  2550000      S
# 487            Malvern    101 Stanhope St      3    h  2500000     VB
# 502            Fitzroy    124 Victoria St      3    h  2478000      S
# 895        Albert Park      59 Moubray St      3    h  2100000     VB
# 1097       Albert Park  121 Richardson St      3    h  1960000      S
# ...                ...                ...    ...  ...      ...    ...
# 11496        St Albans     30 Thorndon Dr      3    h   549500      S
# 11822  North Melbourne     5 Hardwicke St      2    h   516000     SP
# 11844          Prahran       19 Porter St      1    u   515000      S
# 12097          Sunbury    39 Mitchells La      3    h   493000      S
# 12754        Brunswick    1/208 Albion St      1    u   424000     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 456         Marshall  19/08/2017       3.0      3206  ...         2  NaN
# 487         Marshall  23/09/2017       5.9      3144  ...         2  NaN
# 502           Nelson  19/08/2017       2.1      3065  ...         2  NaN
# 895           Cayzer  23/09/2017       3.0      3206  ...         2  NaN
# 1097   hockingstuart  16/09/2017       3.0      3206  ...         2  NaN
# ...              ...         ...       ...       ...  ...       ...  ...
# 11496            YPA  23/09/2017      14.0      3021  ...         1  NaN
# 11822         Jellis  23/09/2017       1.8      3051  ...         1  NaN
# 11844         Biggin  16/09/2017       4.6      3181  ...         1  NaN
# 12097          Raine  09/09/2017      31.7      3429  ...         1  NaN
# 12754         Jellis  26/08/2017       5.2      3056  ...         1  NaN
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 456         152         175.0     1910.0          NaN -37.84663   144.95681
# 487         395         149.0     1880.0          NaN -37.85892   145.03731
# 502         205         106.0     1885.0          NaN -37.79933   144.97932
# 895         137         125.0     1890.0          NaN -37.84388   144.95303
# 1097        152         161.0     1900.0          NaN -37.84662   144.95675
# ...         ...           ...        ...          ...       ...         ...
# 11496       546           NaN        NaN          NaN -37.75020   144.80626
# 11822      1044          79.0     1970.0          NaN -37.79830   144.94687
# 11844       284           NaN        NaN          NaN -37.85018   144.99006
# 12097       650           NaN        NaN          NaN -37.58562   144.71581
# 12754       334          80.0     2009.0          NaN -37.76078   144.96168
#
#                   Regionname Propertycount
# 456    Southern Metropolitan          3280
# 487    Southern Metropolitan          4675
# 502    Northern Metropolitan          5825
# 895    Southern Metropolitan          3280
# 1097   Southern Metropolitan          3280
# ...                      ...           ...
# 11496   Western Metropolitan         14042
# 11822  Northern Metropolitan          6821
# 11844  Southern Metropolitan          7717
# 12097   Western Metropolitan         14092
# 12754  Northern Metropolitan         11918
#
# [62 rows x 21 columns]

# %%
melb_data.loc[melb_data.Car.notnull()]
# Out:
#             Suburb           Address  Rooms Type    Price Method  \
# 0         Mulgrave       35 Bevis St      3    h  9000000     PI
# 1       Canterbury    49 Mangarra Rd      5    h  8000000     VB
# 2         Hawthorn      49 Lisson Gr      4    h  7650000      S
# 3              Kew       15 Barry St      6    h  6500000      S
# 4      Middle Park       136 Page St      5    h  6400000      S
# ...            ...               ...    ...  ...      ...    ...
# 13575     Hawthorn     17/17 Park St      1    u   160000     VB
# 13576       Coburg   171 Moreland Rd      4    h   145000     PI
# 13577       Albion     8/6 Ridley St      1    u   145000     PI
# 13578    Caulfield        30 Pyne St      4    h   131000     PI
# 13579    Footscray  202/51 Gordon St      1    u    85000     PI
#
#             SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0              Hall  29/07/2017      18.8      3170  ...         1  1.0
# 1         Sotheby's  13/05/2017       9.0      3126  ...         5  4.0
# 2      Abercromby's  17/06/2017       5.3      3122  ...         2  4.0
# 3            Jellis  13/08/2016       5.6      3101  ...         6  3.0
# 4          Marshall  09/09/2017       3.0      3206  ...         2  1.0
# ...             ...         ...       ...       ...  ...       ...  ...
# 13575           HAR  08/04/2017       4.6      3122  ...         1  0.0
# 13576        Jellis  04/06/2016       7.8      3058  ...         1  1.0
# 13577        Biggin  28/05/2016      13.9      3020  ...         1  1.0
# 13578        Rodney  25/02/2017       8.9      3162  ...         1  2.0
# 13579       Burnham  03/09/2016       6.4      3011  ...         1  0.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0           744         117.0     1960.0       Monash -37.93168   145.16126
# 1          2079         464.3     1880.0   Boroondara -37.81790   145.06940
# 2          1690         284.0     1863.0   Boroondara -37.82652   145.03052
# 3          1334         365.0     1890.0   Boroondara -37.80290   145.02670
# 4           553         308.0     1920.0          NaN -37.84908   144.95753
# ...         ...           ...        ...          ...       ...         ...
# 13575       322           NaN     2009.0   Boroondara -37.81980   145.03730
# 13576       536         164.0     1910.0     Moreland -37.75550   144.96580
# 13577        36           NaN        NaN     Brimbank -37.78330   144.82660
# 13578       499         155.0     1920.0    Glen Eira -37.88640   145.02420
# 13579         0           NaN     2007.0  Maribyrnong -37.79110   144.89000
#
#                        Regionname Propertycount
# 0      South-Eastern Metropolitan          7113
# 1           Southern Metropolitan          3265
# 2           Southern Metropolitan         11308
# 3           Southern Metropolitan         10331
# 4           Southern Metropolitan          2019
# ...                           ...           ...
# 13575       Southern Metropolitan         11308
# 13576       Northern Metropolitan         11204
# 13577        Western Metropolitan          2185
# 13578       Southern Metropolitan          2379
# 13579        Western Metropolitan          7570
#
# [13518 rows x 21 columns]

# %%
# Assigning data

# %%
melb_data['Type'] = 'sold'

# %%
melb_data.head()
# Out:
#         Suburb         Address  Rooms  Type    Price Method       SellerG  \
# 0     Mulgrave     35 Bevis St      3  sold  9000000     PI          Hall
# 1   Canterbury  49 Mangarra Rd      5  sold  8000000     VB     Sotheby's
# 2     Hawthorn    49 Lisson Gr      4  sold  7650000      S  Abercromby's
# 3          Kew     15 Barry St      6  sold  6500000      S        Jellis
# 4  Middle Park     136 Page St      5  sold  6400000      S      Marshall
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  29/07/2017      18.8      3170  ...         1  1.0       744         117.0
# 1  13/05/2017       9.0      3126  ...         5  4.0      2079         464.3
# 2  17/06/2017       5.3      3122  ...         2  4.0      1690         284.0
# 3  13/08/2016       5.6      3101  ...         6  3.0      1334         365.0
# 4  09/09/2017       3.0      3206  ...         2  1.0       553         308.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude                  Regionname  \
# 0     1960.0       Monash -37.93168   145.16126  South-Eastern Metropolitan
# 1     1880.0   Boroondara -37.81790   145.06940       Southern Metropolitan
# 2     1863.0   Boroondara -37.82652   145.03052       Southern Metropolitan
# 3     1890.0   Boroondara -37.80290   145.02670       Southern Metropolitan
# 4     1920.0          NaN -37.84908   144.95753       Southern Metropolitan
#
#   Propertycount
# 0          7113
# 1          3265
# 2         11308
# 3         10331
# 4          2019
#
# [5 rows x 21 columns]

# %%
melb_data['index_backwards'] = range(len(melb_data), 0, -1)

# %%
melb_data['index_backwards']
# Out:
# 0        13580
# 1        13579
# 2        13578
# 3        13577
# 4        13576
#          ...
# 13575        5
# 13576        4
# 13577        3
# 13578        2
# 13579        1
# Name: index_backwards, Length: 13580, dtype: int32

# %%
melb_data.head()
# Out:
#         Suburb         Address  Rooms  Type    Price Method       SellerG  \
# 0     Mulgrave     35 Bevis St      3  sold  9000000     PI          Hall
# 1   Canterbury  49 Mangarra Rd      5  sold  8000000     VB     Sotheby's
# 2     Hawthorn    49 Lisson Gr      4  sold  7650000      S  Abercromby's
# 3          Kew     15 Barry St      6  sold  6500000      S        Jellis
# 4  Middle Park     136 Page St      5  sold  6400000      S      Marshall
#
#          Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  \
# 0  29/07/2017      18.8      3170  ...  1.0       744         117.0
# 1  13/05/2017       9.0      3126  ...  4.0      2079         464.3
# 2  17/06/2017       5.3      3122  ...  4.0      1690         284.0
# 3  13/08/2016       5.6      3101  ...  3.0      1334         365.0
# 4  09/09/2017       3.0      3206  ...  1.0       553         308.0
#
#    YearBuilt  CouncilArea  Lattitude Longtitude                  Regionname  \
# 0     1960.0       Monash  -37.93168  145.16126  South-Eastern Metropolitan
# 1     1880.0   Boroondara  -37.81790  145.06940       Southern Metropolitan
# 2     1863.0   Boroondara  -37.82652  145.03052       Southern Metropolitan
# 3     1890.0   Boroondara  -37.80290  145.02670       Southern Metropolitan
# 4     1920.0          NaN  -37.84908  144.95753       Southern Metropolitan
#
#    Propertycount index_backwards
# 0           7113           13580
# 1           3265           13579
# 2          11308           13578
# 3          10331           13577
# 4           2019           13576
#
# [5 rows x 22 columns]
